# %%
import matplotlib.pyplot as  plt
days= [1,2,3,4,5,6,7,8]
NOP1 = [5,10,60,52,80,90,99,50]
NOP2 = [5,6,30,66,44,22,39,70]
NOP3 = [9,30,60,77,99,55,45,123]
plt.stackplot(days,NOP1,NOP2,NOP3,labels= ["week1","week2","week3"])
plt.legend(loc =2)
plt.show()
