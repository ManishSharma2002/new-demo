# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8] 
y= [22,25,30,55,40,15,60,23]
y1 = [41,62,90,44,22,25,44,56]
plt.figure(figsize= [8,6])
plt.plot(x,y,label=  "male")
plt.plot(x,y1,label=  "female")
plt.legend(bbox_to_anchor=(0.7,1.1),ncol= 2) # no of columns = ncol
plt.show()
