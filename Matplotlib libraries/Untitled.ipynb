# %%
import matplotlib.pyplot as plt
x= [1,2,3,4,5,6]
y= [55,66,22,77,1,33]
plt.subplot(2,2,1)
plt.title("age")
plt.plot(x,y)


x= [1,2,3,4,5,6]
y= [50,60,20,10,15,30]
plt.subplot(2,2,2)
plt.title("weight")

plt.plot(x,y)


x= [1,2,3,4,5,6]
y= [50,60,20,10,15,30]
plt.subplot(2,2,3)
plt.title("height")
plt.bar(x,y)


x= [1,2,3,4,5,6]
y= [50,60,20,10,15,30]
plt.subplot(2,2,4)
plt.title("body performence")
plt.suptitle("health checkup")
plt.scatter(x,y)
#important :- save the chart in desktop
plt.savefig("save subplot.png", facecolor = "black")
plt.show()
