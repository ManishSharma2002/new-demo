# %%
import matplotlib.pyplot as plt
x= [10,20,90,10,60,80,90,50]
#plt.stem(x,markerfmt = "d",bottom= 5)
plt.plot(x)

plt.show()

# %%
import matplotlib.pyplot as plt
x= [10,20,90,10,60,80,90,50]
plt.stem(x,markerfmt = "d",bottom= 5,orientation = "horizontal")
#plt.plot(x)

plt.show()

# %%
import pandas as pd 
data  = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
df2= df.head(25)
plt.stem(df2["Age"])
plt.plot(df2["Age"])
plt.show()
